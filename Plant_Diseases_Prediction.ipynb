# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict whether a plant is suffering from a disease. We will use different layers and other hyperparameters for building, training and testing this classifictaion model.We will be using tensorflow and keras for this project.

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
#  11.10.2022.ParthKalkar.WeeklyReport.docx
# 'academic transcript.pdf'
#  archive.zip
#  card.jpg
# 'Colab Notebooks'
# 'Copy of 11.11.2022.ParthKalkar.WeeklyReport.docx'
# 'Copy of ParthKalkar_CV.docx'
# 'Copy of ParthKalkar_CV.docx.pdf'
# 'Copy of PIRATE KING Resume - Dark.gdoc'
# 'Copy of PIRATE KING Resume - White.gdoc'
# 'Copy of Reference letter_Germany - Elvina.gdoc'
#  CoverLetter.gdoc
# 'Cover Letter Template + Resources.gdoc'
#  Data
# 'Data Science Practice.gdoc'
#  final_SOP.docx
#  Google-Docs-Invoice-Template-SC-2-G.docx
# 'HABRN - Communication Assignment.gdoc'
# 'HABRN - Emotion Assignment.gdoc'
# 'HABRN - Movement and Training Assignment.gdoc'
# 'How to get started with Drive.pdf'
# 'IMDB Dataset.csv'
#  IMG_20220829_144022_434.jpg
# 'Interview preparation.gdoc'
#  Letter.gdoc
# 'Masters University.gdoc'
# 'Material for SLR.gdoc'
# 'Migration Certificate .pdf'
#  model
# 'MS Admission Enquiry Letter.gdoc'
# 'Online Food Industry Market research.gdoc'
# 'ParthKalkar_CV (1).pdf'
#  ParthKalkar_CV.docx
#  ParthKalkar_CV.pdf
#  passport
# 'Peer Review SLR.gdoc'
# 'PMLDL-D1.1 Report.gdoc'
# 'PMLDL-D1.2 Report.gdoc'
# 'Project proposal.gdoc'
# 'Resume Template + Resources.gdoc'
#  SBES_LeavingCertificate.pdf
#  SOP.gdoc
# 'Structured Abstract.gdoc'
#  Thesis.gdoc
#  Vaccine_certificate_ENG.pdf
#  Vaccine_certificate_RU.pdf

# %% [markdown]
# Next we will import all the required libraries. As we are making a CNN model we will import all the required layers, activations, optimizers, etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from tensorflow.keras.utils import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %% [markdown]
# Now we will observe some of the iamges that are their in our dataset. We will plot 12 images here using the matplotlib library.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/MyDrive/Data/Plant_images_pianalytix/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %% [markdown]
# After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.

# %%
#Converting Images to array 
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))  
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# Now we will convert all the images into numpy array.

# %%
dir = "/content/drive/MyDrive/Data/Plant_images_pianalytix"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# We will also observe the number of images under different classes to see if the dataset is balanced or not

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %% [markdown]
# Next we will observe the shape of the image.

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# Checking the total number of the images which is the length of the labels list.

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %% [markdown]
# Next we will use sklearn train_test_split to split the dataset into testing and training data. Here I have taken test size as 0.2 so my data will be divided into 80% training and 20% testing data.

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 85, 85, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 16)        4624
#
#  max_pooling2d_1 (MaxPooling  (None, 42, 42, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 28224)             0
#
#  dense (Dense)               (None, 8)                 225800
#
#  dense_1 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 231,347
# Trainable params: 231,347
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %% [markdown]
# Next we will split the dataset into validation and training data.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 10 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already raeched a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 11s 397ms/step - loss: 1.1135 - accuracy: 0.3785 - val_loss: 1.0810 - val_accuracy: 0.5556
# Epoch 2/50
# 5/5 [==============================] - 1s 169ms/step - loss: 1.0657 - accuracy: 0.4601 - val_loss: 1.0188 - val_accuracy: 0.4514
# Epoch 3/50
# 5/5 [==============================] - 1s 166ms/step - loss: 0.9816 - accuracy: 0.4427 - val_loss: 0.9524 - val_accuracy: 0.3264
# Epoch 4/50
# 5/5 [==============================] - 1s 168ms/step - loss: 0.8937 - accuracy: 0.4774 - val_loss: 0.8469 - val_accuracy: 0.5903
# Epoch 5/50
# 5/5 [==============================] - 1s 166ms/step - loss: 0.7934 - accuracy: 0.6545 - val_loss: 0.7632 - val_accuracy: 0.6111
# Epoch 6/50
# 5/5 [==============================] - 1s 165ms/step - loss: 0.7090 - accuracy: 0.6493 - val_loss: 0.7041 - val_accuracy: 0.5972
# Epoch 7/50
# 5/5 [==============================] - 1s 167ms/step - loss: 0.6494 - accuracy: 0.6476 - val_loss: 0.6475 - val_accuracy: 0.6250
# Epoch 8/50
# 5/5 [==============================] - 1s 167ms/step - loss: 0.6001 - accuracy: 0.6632 - val_loss: 0.6077 - val_accuracy: 0.6250
# Epoch 9/50
# 5/5 [==============================] - 1s 167ms/step - loss: 0.5637 - accuracy: 0.6649 - val_loss: 0.5793 - val_accuracy: 0.6250
# Epoch 10/50
# 5/5 [==============================] - 1s 167ms/step - loss: 0.5394 - accuracy: 0.6632 - val_loss: 0.5591 - val_accuracy: 0.6250
# Epoch 11/50
# 5/5 [==============================] - 1s 168ms/step - loss: 0.5194 - accuracy: 0.6667 - val_loss: 0.5447 - val_accuracy: 0.6250
# Epoch 12/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.5028 - accuracy: 0.6667 - val_loss: 0.5301 - val_accuracy: 0.6250
# Epoch 13/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.4917 - accuracy: 0.6667 - val_loss: 0.5195 - val_accuracy: 0.6250
# Epoch 14/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.4813 - accuracy: 0.6667 - val_loss: 0.5106 - val_accuracy: 0.6250
# Epoch 15/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.4715 - accuracy: 0.6684 - val_loss: 0.5009 - val_accuracy: 0.6250
# Epoch 16/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.4631 - accuracy: 0.6684 - val_loss: 0.4923 - val_accuracy: 0.6250
# Epoch 17/50
# 5/5 [==============================] - 1s 166ms/step - loss: 0.4532 - accuracy: 0.6684 - val_loss: 0.4822 - val_accuracy: 0.6250
# Epoch 18/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.4449 - accuracy: 0.6684 - val_loss: 0.4739 - val_accuracy: 0.6250
# Epoch 19/50
# 5/5 [==============================] - 1s 167ms/step - loss: 0.4371 - accuracy: 0.6684 - val_loss: 0.4660 - val_accuracy: 0.6250
# Epoch 20/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.4296 - accuracy: 0.6684 - val_loss: 0.4589 - val_accuracy: 0.6250
# Epoch 21/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4225 - accuracy: 0.6684 - val_loss: 0.4516 - val_accuracy: 0.6250
# Epoch 22/50
# 5/5 [==============================] - 1s 166ms/step - loss: 0.4157 - accuracy: 0.6684 - val_loss: 0.4456 - val_accuracy: 0.6250
# Epoch 23/50
# 5/5 [==============================] - 1s 168ms/step - loss: 0.4084 - accuracy: 0.6684 - val_loss: 0.4393 - val_accuracy: 0.6250
# Epoch 24/50
# 5/5 [==============================] - 1s 167ms/step - loss: 0.4003 - accuracy: 0.6684 - val_loss: 0.4319 - val_accuracy: 0.6250
# Epoch 25/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.3966 - accuracy: 0.6684 - val_loss: 0.4264 - val_accuracy: 0.6250
# Epoch 26/50
# 5/5 [==============================] - 1s 168ms/step - loss: 0.3887 - accuracy: 0.6684 - val_loss: 0.4208 - val_accuracy: 0.6250
# Epoch 27/50
# 5/5 [==============================] - 1s 167ms/step - loss: 0.3833 - accuracy: 0.6684 - val_loss: 0.4158 - val_accuracy: 0.6250
# Epoch 28/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.3785 - accuracy: 0.6684 - val_loss: 0.4105 - val_accuracy: 0.6250
# Epoch 29/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.3737 - accuracy: 0.6684 - val_loss: 0.4079 - val_accuracy: 0.6250
# Epoch 30/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3695 - accuracy: 0.6684 - val_loss: 0.4014 - val_accuracy: 0.6250
# Epoch 31/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.3627 - accuracy: 0.6684 - val_loss: 0.3972 - val_accuracy: 0.6250
# Epoch 32/50
# 5/5 [==============================] - 1s 168ms/step - loss: 0.3584 - accuracy: 0.6701 - val_loss: 0.3932 - val_accuracy: 0.6250
# Epoch 33/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.3537 - accuracy: 0.6701 - val_loss: 0.3897 - val_accuracy: 0.6250
# Epoch 34/50
# 5/5 [==============================] - 1s 203ms/step - loss: 0.3501 - accuracy: 0.6701 - val_loss: 0.3851 - val_accuracy: 0.6250
# Epoch 35/50
# 5/5 [==============================] - 1s 196ms/step - loss: 0.3462 - accuracy: 0.6701 - val_loss: 0.3813 - val_accuracy: 0.6250
# Epoch 36/50
# 5/5 [==============================] - 1s 197ms/step - loss: 0.3419 - accuracy: 0.6701 - val_loss: 0.3783 - val_accuracy: 0.6250
# Epoch 37/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.3388 - accuracy: 0.6701 - val_loss: 0.3744 - val_accuracy: 0.6250
# Epoch 38/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3354 - accuracy: 0.6684 - val_loss: 0.3716 - val_accuracy: 0.6250
# Epoch 39/50
# 5/5 [==============================] - 1s 227ms/step - loss: 0.3324 - accuracy: 0.6701 - val_loss: 0.3699 - val_accuracy: 0.6250
# Epoch 40/50
# 5/5 [==============================] - 1s 231ms/step - loss: 0.3297 - accuracy: 0.6701 - val_loss: 0.3669 - val_accuracy: 0.6250
# Epoch 41/50
# 5/5 [==============================] - 1s 197ms/step - loss: 0.3270 - accuracy: 0.6701 - val_loss: 0.3641 - val_accuracy: 0.6250
# Epoch 42/50
# 5/5 [==============================] - 1s 193ms/step - loss: 0.3248 - accuracy: 0.6701 - val_loss: 0.3624 - val_accuracy: 0.6250
# Epoch 43/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.3231 - accuracy: 0.6701 - val_loss: 0.3606 - val_accuracy: 0.6250
# Epoch 44/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.3210 - accuracy: 0.6701 - val_loss: 0.3582 - val_accuracy: 0.6250
# Epoch 45/50
# 5/5 [==============================] - 1s 200ms/step - loss: 0.3188 - accuracy: 0.6701 - val_loss: 0.3562 - val_accuracy: 0.6250
# Epoch 46/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3179 - accuracy: 0.6701 - val_loss: 0.3555 - val_accuracy: 0.6250
# Epoch 47/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3159 - accuracy: 0.6701 - val_loss: 0.3534 - val_accuracy: 0.6250
# Epoch 48/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.3157 - accuracy: 0.6701 - val_loss: 0.3534 - val_accuracy: 0.6250
# Epoch 49/50
# 5/5 [==============================] - 1s 195ms/step - loss: 0.3129 - accuracy: 0.6701 - val_loss: 0.3495 - val_accuracy: 0.6250
# Epoch 50/50
# 5/5 [==============================] - 1s 164ms/step - loss: 0.3112 - accuracy: 0.6701 - val_loss: 0.3487 - val_accuracy: 0.6250

# %% [markdown]
# Saving the model using different techniques.

# %%
model.save("/content/drive/MyDrive/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/MyDrive/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/MyDrive/plant_model_weights.h5')

# %% [markdown]
# Next we will plot the accuracy of the model for the trainig history.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Evaluating the model to know the accuracy of the model.

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2964 - accuracy: 0.6889
# Test Accuracy: 68.88889074325562

# %% [markdown]
# Next we will use our model to predict predicting the testing dataset label.

# %%
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 23ms/step

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F0D7374DE10>

# %% [markdown]
# Printing out the original and the predicted label.

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the plant diseases using the image supplied to model.
# This model is highly beneficial as it can be used by different agricultural firms and farmers to increase their yield and stop wastage of crops due to disease.
